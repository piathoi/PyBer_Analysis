# %%
#make sure plot is displayed inline within the JN directly below the code cell that producted it
# %matplotlib inline

# %%
#import dependencies
import matplotlib.pyplot as plt

# %%
#set the x-axis to a list of strings for each month
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#create the plot - line chart
plt.plot(x_axis, y_axis)

# %%
#switch from using MATLAB to the object_oriented interface method, use ax.plot() instead of plt.plot()
#to create figure: use fig, ax = plt.subplots()
#to define axes, use ax.plot()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
#cell 6 can be written like this:
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
#create the plot
plt.plot(x_axis, y_axis)

#plt.show() looks for all the active figure objects and opens a window that displays them is you have 2 or more sets of data to plot
plt.show()

# %%
#create the plot and add a label for the legend
plt.plot(x_axis, y_axis, marker = "*", color = "blue", linewidth = 2, label='Boston')

#create labels for the x and y axes
plt.xlabel("date")
plt.ylabel("fare($)")

#set the y limit between 0 and 45
plt.ylim(0,45)

#create a title
plt.title("PyBer Fare by Month")

#add a grid
plt.grid()

#add a legend
plt.legend()

#use slim() to show months Jan thro June on graph
plt.xlim("Jan","June") 
# plt.xlim(0,5) is okay too

#change the figure size to 20 pixels wide by 1- pixels high using figure
plt.figure(figsize=(20,10)) 
# plt.subplots(figsize=(20,10)) is okay too

# %%
# SKILL DRILL

#create the plot and add a label for the legend, market diamond, color green
plt.plot(x_axis, y_axis, marker = "d", color = "green", linewidth = 2, label='Boston')

#create labels for the x and y axes
plt.xlabel("date")
plt.ylabel("fare($)")

#set the y limit between 0 and 45
plt.ylim(0,45)

#create a title
plt.title("PyBer Fare by Month")

#add a grid
plt.grid()

#add a legend
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %% [markdown]
# # Bar chart

# %%
#create the plot - bar chart
plt.bar(x_axis, y_axis, color = "green", label='Boston')

#create labels for the x and y axes
plt.xlabel("Date")
plt.ylabel("Fare($)")

#create a title
plt.title("PyBer Fare by Month")

#add the legend
plt.legend()

# %% [markdown]
# ## Horizontal bar chart

# %%
#create the plot - horizontal bar chart
plt.barh(x_axis, y_axis, color = "pink", label='Boston')

#create labels for the x and y axes
plt.xlabel("Fare($)")
plt.ylabel("Date")

#create a title
plt.title("PyBer Fare by Month")

#add the legend
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)

#change bar to black with New York label
ax.bar(x_axis, y_axis, color="k", label='New York')
# ax.bar(x_axis, y_axis, color="black", label='New York') also works
# Out:
# <BarContainer object of 12 artists>

# %%
#create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="cyan", label='Chicago')

plt.title = "PyBer Fare by Month"

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# ## Scatter Plot using MATLAB method

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#using plt.plot() doesnt work because it will create a line plot.
#insert lowercase "o" 
plt.plot(x_axis, y_axis, 'o')

# %%
#create scatter plot using plt.scatter can also works
plt.scatter(x_axis, y_axis)

# %%
#create the plot 
plt.scatter(y_axis, x_axis, color = "red", label='Chicago')

#create labels for the x and y axes
plt.ylabel("Fare($)")
plt.xlabel("Date")

#create a title
plt.title("PyBer Fare by Month")

#add the legend
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ww/6zkxc6655hl95h_t9d50nch00000gn/T/ipykernel_45962/862737564.py in <module>
#       7
#       8 #create a title
# ----> 9 plt.title("PyBer Fare by Month")
#      10
#      11 #add the legend
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # Bubble Chart using Matlab method

# %%
plt.scatter(x_axis, y_axis)

# %%
#change size using "s" size parameter
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
#make markers larger
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*8)

# %%
plt.scatter(x_axis, y_axis_larger)

# %%
#using list comprehension technique to multiply each data point in the y_axis list
# new_list = [expression for item in list if conditional]
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %% [markdown]
# # Scatter Plot using Object-Oriented Interface

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %% [markdown]
# # Bubble Chart using Object-Oriented Interface

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(x_axis, y_axis, s=y_axis, color="blue", label ='Boston', linewidth = 2, edgecolors = "black")

#Add a label that will be added to the legend.
ax.plot(x_axis, y_axis, label='Boston')

#add title
ax.set_title("PyBer Fare by Month")

#add legend
ax.legend()

# %% [markdown]
# # Pie Chart using MATLAB

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
#increase the size of pit chart
plt.subplots(figsize=(8,8))

#add percentage and explode the largest percentage
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

#autopct parameter: add percentage of each wedge on the pie chart
#.1f% formats the number as percentage
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9aa671b670>,
# ...
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.32930826971286276, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452757, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.23338752507546193, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.460981299980763, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065241, 0.5724820419136908, '11.7%'),
# ...

# %%
#Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen",
          "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %% [markdown]
# # Create Pie Chart using Object-Oriented Interface

# %%
fig, ax = plt.subplots()
ax.pie(y_axis, labels=x_axis)
plt.show()

# %% [markdown]
# # Add Error Bars to a Line Chart

# %%
plt.errorbar(x,y, yerr)
